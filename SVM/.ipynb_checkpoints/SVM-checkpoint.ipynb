# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from skimage.io import imread

# %%
cat_image = imread("https://images-na.ssl-images-amazon.com/images/I/91osah3bwPL._AC_SX522_.jpg")

# %%
type(cat_image)
# Out:
# numpy.ndarray

# %%
cat_image.shape
# Out:
# (699, 522, 3)

# %% [markdown]
# - red, green, blu - sempre

# %%
# primo pixel
cat_image[0,0]
# Out:
# array([254, 255, 244], dtype=uint8)

# %%
# prima riga
cat_image[0, :, :]
# Out:
# array([[254, 255, 244],
#        [254, 255, 248],
#        [254, 255, 251],
#        ...,
#        [255, 254, 251],
#        [255, 254, 251],
#        [255, 255, 251]], dtype=uint8)

# %%
# prima colona
cat_image[:, 0, :]
# Out:
# array([[254, 255, 244],
#        [254, 255, 255],
#        [254, 253, 255],
#        ...,
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255]], dtype=uint8)

# %%
# canale rosso
cat_image[:, :, 0]
# Out:
# array([[254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 255, 255, 255],
#        [254, 254, 254, ..., 240, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %% [markdown]
# # Support Vector Machines:

# %%
plt.figure(figsize=(10,8)) # inches
plt.imshow(cat_image)
plt.xticks([]) # nessun tick
plt.yticks([])
plt.show()

# %%
plt.figure(figsize=(10,8)) # inches
plt.imshow(cat_image[100:300, 100:600])
plt.xticks([]) # nessun tick
plt.yticks([])
plt.show()

# %%
cat_image # unit=8 molto non apropriato per convolution, potrebbe far tornare numeri sbagliati
# cambiamo in float
# prende solo intera parte 40,9 = 40
cat_image_for_domeling = cat_image.astype('float')

# %%
plt.figure(figsize=(10,8)) # inches
plt.imshow(cat_image[100:300, 100:600] * 5) # multiplico per 5, unit=8
plt.xticks([]) # nessun tick
plt.yticks([])
plt.show()
# overflow - abbiamo superato il tipo dei dati

# %%
plt.figure(figsize=(10,8)) # inches
plt.imshow(cat_image[100:300, 100:600] * 5) # multiplico per 5, unit=8
plt.xticks([]) # nessun tick
plt.yticks([])
plt.show()

# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split

# %%
data, target = load_boston().data, load_boston().target

# %%
data.shape
# Out:
# (506, 13)

# %%
target.shape
# Out:
# (506,)

# %%
train_Val_data, test_data, train_val_target, test_target = train_test_split(data, target, train_size=0.8)

# %%
train_Val_data.shape
# Out:
# (404, 13)

# %%
0.7 * 506
# Out:
# 354.2

# %%
train_data, val_data, train_target, val_target = train_test_split(train_Val_data, train_val_target, train_size=len(test_target))

# %%
# dava 10 ot vece 30 procenta = 0.1

# %%
train_data.shape
# Out:
# (102, 13)

# %%
# 63% : 7 % : 30 %
# 
0.6 * 506
# Out:
# 303.59999999999997

# %%
len(test_target)
# Out:
# 102

# %% [markdown]
# [arXiv.org](https://arxiv.org/)
